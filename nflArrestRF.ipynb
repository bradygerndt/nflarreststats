# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
##Final data with team network stats
df = pd.read_csv('./data/final_networked_by_team.csv')
# Out:
# /home/brady/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33282 entries, 0 to 33281
# Data columns (total 36 columns):
# No                       32704 non-null float64
# name                     33282 non-null object
# Age                      33099 non-null float64
# Pos                      21920 non-null object
# G                        33282 non-null float64
# GS                       33250 non-null float64
# Wt                       33275 non-null float64
# Ht                       33275 non-null object
# College                  33264 non-null object
# BirthDate                33276 non-null object
# Yrs                      33282 non-null object
# AV                       33281 non-null float64
# team                     33282 non-null object
# year                     33282 non-null float64
# Draft_Team               23776 non-null object
# Draft_Round              23776 non-null object
# Draft_Pick               23776 non-null float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33282 entries, 0 to 33281
# Data columns (total 36 columns):
# No                       32704 non-null float64
# name                     33282 non-null object
# Age                      33099 non-null float64
# Pos                      21920 non-null object
# G                        33282 non-null float64
# GS                       33250 non-null float64
# Wt                       33275 non-null float64
# Ht                       33275 non-null object
# College                  33264 non-null object
# BirthDate                33276 non-null object
# Yrs                      33282 non-null object
# AV                       33281 non-null float64
# team                     33282 non-null object
# year                     33282 non-null float64
# Draft_Team               23776 non-null object
# Draft_Round              23776 non-null object
# Draft_Pick               23776 non-null float64
# ...

# %%
df.describe()
# Out:
#                  No           Age             G            GS            Wt  \
# count  32704.000000  33099.000000  33282.000000  33250.000000  33275.000000
# mean      53.748012     26.651440     11.523286      5.756872    243.628400
# std       28.442887      3.402038      5.163789      6.311442     45.081399
# min        0.000000     20.000000      1.000000      0.000000    150.000000
# 25%       28.000000     24.000000      7.000000      0.000000    205.000000
# 50%       54.000000     26.000000     14.000000      3.000000    236.000000
# 75%       80.000000     29.000000     16.000000     12.000000    281.000000
# max       99.000000     47.000000     16.000000     16.000000    376.000000
#
#                  AV          year    Draft_Pick  crimeCount         DUI  \
# count  33281.000000  33282.000000  23776.000000  679.000000  679.000000
# mean       3.370121   2008.205186    104.223082    1.069219    0.290133
# ...

# %%
crimeList = ['crimeCount','DUI','Other','Drugs','Domestic Violence','Resisting','Assault / Battery','Gun','Alcohol','License / Traffic','Disorderly conduct','Sex','Theft / Burglary','Murder / Manslaughter','Animal Abuse','AV']

X = df.drop(crimeList, axis=1)
y = df['crimeCount']

X.head()
# Out:
#      No            name   Age  Pos     G   GS     Wt      Ht  \
# 0  45.0      Josh Baker  25.0  NaN  11.0  0.0  244.0   3-Jun
# 1  34.0     Chris Smith  24.0  NaN   3.0  0.0  186.0  10-May
# 2  26.0  Tramaine Brock  23.0  NaN  11.0  0.0  197.0  10-May
# 3  26.0  Tramaine Brock  24.0  NaN  16.0  0.0  197.0  10-May
# 4  26.0  Tramaine Brock  25.0  RCB  16.0  7.0  197.0  10-May
#
#                                    College BirthDate   Yrs team    year  \
# 0      “Delware, Northwest Missouri State”  12/25/86  Rook  NYJ  2011.0
# 1      “Highland J.C., Northern Illionois”   6/23/87  Rook   LA  2011.0
# 2  “Mississippi Gulf Coast J.C.,Bellhaven”   8/20/88     1   SF  2011.0
# 3  “Mississippi Gulf Coast J.C.,Bellhaven”   8/20/88     2   SF  2012.0
# 4  “Mississippi Gulf Coast J.C.,Bellhaven”   8/20/88     3   SF  2013.0
#
#   Draft_Team Draft_Round  Draft_Pick Draft_Year  Team_Degrees  Team_Closeness  \
# 0        NaN         NaN         NaN        NaN          33.0        0.369705
# ...
