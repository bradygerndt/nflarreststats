# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
##Final data with team network stats
df = pd.read_csv('./data/final_networked_by_team.csv')

# %%
df.head()
# Out:
#      No            name   Age  Pos     G   GS     Wt    Ht  \
# 0  45.0      Josh Baker  25.0  NaN  11.0  0.0  244.0  75.0
# 1  34.0     Chris Smith  24.0  NaN   3.0  0.0  186.0  70.0
# 2  26.0  Tramaine Brock  23.0  NaN  11.0  0.0  197.0  70.0
# 3  26.0  Tramaine Brock  24.0  NaN  16.0  0.0  197.0  70.0
# 4  26.0  Tramaine Brock  25.0  RCB  16.0  7.0  197.0  70.0
#
#                                  College BirthDate        ...        Alcohol  \
# 0      Delware, Northwest Missouri State  12/25/86        ...            NaN
# 1      Highland J.C., Northern Illionois   6/23/87        ...            NaN
# 2  Mississippi Gulf Coast J.C.,Bellhaven   8/20/88        ...            NaN
# 3  Mississippi Gulf Coast J.C.,Bellhaven   8/20/88        ...            NaN
# 4  Mississippi Gulf Coast J.C.,Bellhaven   8/20/88        ...            NaN
#
#    License / Traffic Disorderly conduct  Sex Theft / Burglary  \
# 0                NaN                NaN  NaN              NaN
# 1                NaN                NaN  NaN              NaN
# 2                NaN                NaN  NaN              NaN
# 3                NaN                NaN  NaN              NaN
# 4                NaN                NaN  NaN              NaN
#
#    Murder / Manslaughter  Animal Abuse  Team_Degrees  Team_Closeness  \
# 0                    NaN           NaN          33.0        0.369705
# 1                    NaN           NaN          27.0        0.362264
# 2                    NaN           NaN          36.0        0.367816
# 3                    NaN           NaN          36.0        0.367816
# 4                    NaN           NaN          36.0        0.367816
#
#    Team_Betweenness
# 0          0.050261
# 1          0.037319
# 2          0.050009
# 3          0.050009
# 4          0.050009
#
# [5 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33282 entries, 0 to 33281
# Data columns (total 36 columns):
# No                       32704 non-null float64
# name                     33282 non-null object
# Age                      33276 non-null float64
# Pos                      21920 non-null object
# G                        33282 non-null float64
# GS                       33250 non-null float64
# Wt                       33275 non-null float64
# Ht                       815 non-null float64
# College                  33264 non-null object
# BirthDate                33276 non-null object
# Yrs                      33282 non-null object
# AV                       33281 non-null float64
# team                     33282 non-null object
# year                     33282 non-null float64
# Draft_Team               23776 non-null object
# Draft_Round              23776 non-null float64
# Draft_Pick               23776 non-null float64
# Draft_Year               23753 non-null float64
# crimeCount               679 non-null float64
# DUI                      679 non-null float64
# Other                    679 non-null float64
# Drugs                    679 non-null float64
# Domestic Violence        679 non-null float64
# Resisting                679 non-null float64
# Assault / Battery        679 non-null float64
# Gun                      679 non-null float64
# Alcohol                  679 non-null float64
# License / Traffic        679 non-null float64
# Disorderly conduct       679 non-null float64
# Sex                      679 non-null float64
# Theft / Burglary         679 non-null float64
# Murder / Manslaughter    679 non-null float64
# Animal Abuse             679 non-null float64
# Team_Degrees             33282 non-null float64
# Team_Closeness           33282 non-null float64
# Team_Betweenness         33282 non-null float64
# dtypes: float64(29), object(7)
# memory usage: 9.1+ MB

# %%
df.describe()
# Out:
#                  No           Age             G            GS            Wt  \
# count  32704.000000  33276.000000  33282.000000  33250.000000  33275.000000
# mean      53.748012     26.646923     11.523286      5.756872    243.628400
# std       28.442887      3.399451      5.163789      6.311442     45.081399
# min        0.000000     20.000000      1.000000      0.000000    150.000000
# 25%       28.000000     24.000000      7.000000      0.000000    205.000000
# 50%       54.000000     26.000000     14.000000      3.000000    236.000000
# 75%       80.000000     29.000000     16.000000     12.000000    281.000000
# max       99.000000     47.000000     16.000000     16.000000    376.000000
#
#                Ht            AV          year   Draft_Round    Draft_Pick  \
# count  815.000000  33281.000000  33282.000000  23776.000000  23776.000000
# mean    74.184049      3.370121   2008.205186      3.584118    104.223082
# std      2.502184      3.601035      4.879879      2.049542     93.181459
# min     66.000000     -5.000000   2000.000000      1.000000      1.000000
# 25%     73.000000      1.000000   2004.000000      2.000000     40.000000
# 50%     74.000000      2.000000   2008.000000      3.000000     91.000000
# 75%     76.000000      6.000000   2012.000000      5.000000    158.000000
# max     80.000000     26.000000   2016.000000     12.000000   2010.000000
#
#              ...            Alcohol  License / Traffic  Disorderly conduct  \
# count        ...         679.000000         679.000000          679.000000
# mean         ...           0.060383           0.058910            0.051546
# std          ...           0.244480           0.270593            0.221272
# min          ...           0.000000           0.000000            0.000000
# 25%          ...           0.000000           0.000000            0.000000
# 50%          ...           0.000000           0.000000            0.000000
# 75%          ...           0.000000           0.000000            0.000000
# max          ...           2.000000           3.000000            1.000000
#
#               Sex  Theft / Burglary  Murder / Manslaughter  Animal Abuse  \
# count  679.000000        679.000000             679.000000    679.000000
# mean     0.026510          0.027982               0.008837      0.008837
# std      0.160763          0.173751               0.093656      0.093656
# min      0.000000          0.000000               0.000000      0.000000
# 25%      0.000000          0.000000               0.000000      0.000000
# 50%      0.000000          0.000000               0.000000      0.000000
# 75%      0.000000          0.000000               0.000000      0.000000
# max      1.000000          2.000000               1.000000      1.000000
#
#        Team_Degrees  Team_Closeness  Team_Betweenness
# count  33282.000000    33282.000000      33282.000000
# mean      36.281233        0.364585          0.055353
# std        7.881125        0.009935          0.016987
# min       21.000000        0.341232          0.022637
# 25%       31.000000        0.358655          0.042566
# 50%       37.000000        0.365947          0.056650
# 75%       41.000000        0.370656          0.070111
# max       50.000000        0.382979          0.085786
#
# [8 rows x 29 columns]

# %%
dropList = ['name','crimeCount','DUI','Other','Drugs','Domestic Violence','Resisting','Assault / Battery','Gun','Alcohol','License / Traffic','Disorderly conduct','Sex','Theft / Burglary','Murder / Manslaughter','Animal Abuse','AV']

X = df.drop(dropList, axis=1)
y = df['crimeCount']

X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33282 entries, 0 to 33281
# Data columns (total 19 columns):
# No                  32704 non-null float64
# Age                 33276 non-null float64
# Pos                 21920 non-null object
# G                   33282 non-null float64
# GS                  33250 non-null float64
# Wt                  33275 non-null float64
# Ht                  815 non-null float64
# College             33264 non-null object
# BirthDate           33276 non-null object
# Yrs                 33282 non-null object
# team                33282 non-null object
# year                33282 non-null float64
# Draft_Team          23776 non-null object
# Draft_Round         23776 non-null float64
# Draft_Pick          23776 non-null float64
# Draft_Year          23753 non-null float64
# Team_Degrees        33282 non-null float64
# Team_Closeness      33282 non-null float64
# Team_Betweenness    33282 non-null float64
# dtypes: float64(13), object(6)
# memory usage: 4.8+ MB

# %%
##Handling categorical data
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 22)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 150)
rfc.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-7e1740436dcc> in <module>()
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 rfc = RandomForestClassifier(n_estimators = 150)
# ----> 3 rfc.fit(X_train, y_train)
#
# /home/brady/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     244         """
#     245         # Validate or convert input data
# --> 246         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     247         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     248         if sample_weight is not None:
#
# /home/brady/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     400                                       force_all_finite)
#     401     else:
# --> 402         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     403
#     404         if ensure_2d:
#
# ValueError: could not convert string to float: 'Cincinnati Bengals '
